-- %%
CREATE OR REPLACE TABLE employee.gold.workforce_gold
USING DELTA
AS
SELECT *
FROM employee.silver.workforce_clean

-- %%
select * from employee.gold.workforce_gold

-- %%
CREATE OR REPLACE TABLE employee.gold.attendance_gold
USING DELTA
AS
SELECT *
FROM employee.silver.attendance_clean

-- %%
select * from employee.gold.attendance_gold

-- %%
CREATE OR REPLACE TABLE employee.gold.performance_gold
USING DELTA
AS
SELECT *
FROM employee.silver.performance_clean

-- %%
select * from employee.gold.performance_gold

-- %%
CREATE OR REPLACE TABLE employee.gold.compensation_gold
USING DELTA
AS
SELECT *
FROM employee.silver.compensation_clean

-- %%
select * from employee.gold.compensation_gold
