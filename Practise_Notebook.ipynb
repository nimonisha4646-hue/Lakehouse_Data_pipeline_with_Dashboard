# %%
df = spark.read.format("csv") \
.option("header","true") \
.option("inferSchema","true") \
.load("/Volumes/practise/task/volume_demo/cars.csv")

df.write.saveAsTable("practise.task.car_table")

# %%
spark.sql("DESCRIBE DETAIL default.car_table").show(truncate=False)

# %%
catalog= "practise"
schema="task"

# %%
GENAI_USER ="nisha.k@datapattern.ai"

# %%
spark.sql(f"grant select on table {catalog}.{schema}.car_table to `{GENAI_USER}`")

# %%
# %sql
GRANT SELECT ON TABLE practise.task.car_table TO `nisha.k@datapattern.ai`;

# %%
# %sql
SHOW GRANTS ON TABLE practise.task.car_table;

# %%
# %sql
select * from car_table
